# %% [markdown]
# # PROYECTO - MINERIA DE DATOS

# %% [markdown]
# ## <b>Actividad 3.</b>

# %% [markdown]
# #### Los datos utilizados para responder el problema plnateado fueron obtenidos de las diferentes instituciones de gobierno encargadas en almacenar la información sobre la importación de vehículos.
#
# El problema plnateado es el siguiente *"Investigar sobre la tasa de crecimiento anual del parque vehicular, y buscar si estos datos tienen relación con el excesivo tránsito de la ciudad y otros males vehiculares como los accidentes de tránsitos."*
#
# La informarción se obtuvo de los siguientes enlaces;
# #### *<a href="http://transito.gob.gt/wp-content/uploads/2020/01/Boletin-No_-12-2019-15.pdf" target="_blank">Boletín estadístico</a>
# #### *<a href="https://portal.sat.gob.gt/portal/alza-e-importacion-vehiculos/" target="_blank">Alza de importación de vehículos</a>
# #### *<a href="https://www.ine.gob.gt/ine/estadisticas/bases-de-datos/accidentes-de-transito/" target="_blank">INE, accidentes de tránsito</a>
# #### *<a href="https://www.censopoblacion.gt/descarga" target="_blank">Censo 2018</a>
#
# Para la limpieza de datos se utilizó una metodología para garantizar la calidad de los datos.
#
# 1) Análisis de datos: en esta etapa se determinaron qué tipo de errores deben ser eliminados, de una forma manual. Se determinó que se debía cambiar el símbolo "|" por ",". Para poder lograr la lectura de los datos. De igual forma, se transformaron de formato a tipo .CSV (Comma delimited).
#
# 2) Verificación: en esta etapa de testearon los datos y se evaluaron.
#
# 3) Se refrescó el data warehouse, listo para ser trabajado.

# %% [markdown]
# #### Exploración de datos

# %% [markdown]
# Descripción y observación de variables
#
# | Variable | Descripción | Tipo |
# | --- | --- | --- |
# | Pais_de_Proveniencia | País de origen | Categórica |
# | Aduano de Ingreso | Lugar de ingreso | Categórica |
# | Fecha de la Poliza | Fecha que se creo la poliza | Categórica |
# | Partida Arancelaria | Impuesto | Categórica |
# | Modelo del vehículo | Año del carro | Numérica |
# | Marca | Fabricante | Categórica |
# | Linea | Tipo de automóvil | Categórica |
# | Centimetros cubicos | Tamaño de motor | Numérica |
# | Distintivo | Tipo | Categórica |
# | Tipo de vehículo | Tipo | Categórica |
# | Tipo de impuesto | Impuesto | Categórica |
# | Tipo de combustible | Tipo | Categórica |
# | Asientos | Cantidad de asientos | Numérica |
# | Puertas | Cantidad de puertas | Numérica |
# | Tonelaje | Cantidad de toneladas | Numérica |
# | Valor CIF | Valor | Numérica |
# | Impuesto | Impuesto | Numérica |

# %% [markdown]
# #### Distribución normal
# Como parte del proyecto se investigó si las varaibles tenían un comportamiento de distribución normal, para poder responder se gráficaron las variables para ver si su comportamiento la seguían. Como conclusión se pudo ver que ninguna varaible seguía la distribución normal.

# %% [markdown]
# ![Asientos.PNG](attachment:Asientos.PNG)
# ![Partida%20Arancelaria.PNG](attachment:Partida%20Arancelaria.PNG)
# ![Puertas.PNG](attachment:Puertas.PNG)
# ![Tipo%20de%20gasolina.PNG](attachment:Tipo%20de%20gasolina.PNG)
# ![Tonelaje.PNG](attachment:Tonelaje.PNG)
# ![Valor%20CIF.PNG](attachment:Valor%20CIF.PNG)

# %% [markdown]
# #### Frecuencia
# Las tablas de frecuencia indica la cantidad de veces que se repite un valor es un rango asignado, para nuestro uso esta información es irelevante.
