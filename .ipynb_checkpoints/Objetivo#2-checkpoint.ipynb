# %%
# Librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ene2016 = pd.read_csv('2016\Enero2016.csv')
feb2016 = pd.read_csv('2016\Febrero2016.csv')
mar2016 = pd.read_csv('2016\Marzo2016.csv')
may2016 = pd.read_csv('2016\Mayo2016.csv')
jun2016 = pd.read_csv('2016\Junio2016.csv')
jul2016 = pd.read_csv('2016\Julio2016.csv')
ago2016 = pd.read_csv('2016\Agosto2016.csv')
oct2016 = pd.read_csv('2016\Octubre2016.csv')
dic2016 = pd.read_csv('2016\Diciembre2016.csv')
dic2016.sort_values(by ='Modelo_del_Vehiculo', ascending=True)
#Usando la columna "Modelo_del_vehiculo" 
#vamos a contar cuantos vehiculos muy viejos vs viejos vs nuevos traen al pais, se va considerar nuevos 
#a los vehiculos que sean minimo un año atras al año en que fueron traidos, por ejemplo si el año 2016 
#solo los vehiculos que sean modelos 2015, 2016 y 2017 se cosideran entre nuevos, viejos seran aquellos que 
#a partir de ese años atras esten 5 atras, por ejemplo en el año 2016 estaran en viejos todos los que sean 
#modelos entre 2010 y 2014, y por ultimo muy viejos seran todos los modelos de los restos de años no mencionados.
# Out:
#       Pais_de_Proveniencia        Aduana de Ingreso  Fecha de la Poliza  \
# 25851                CHINA               TECUN UMAN          19/12/2016
# 1485        ESTADOS UNIDOS               TECUN UMAN          12/12/2016
# 20802   ALEMANIA REP. FED.               TECUN UMAN          13/12/2016
# 24323       ESTADOS UNIDOS               TECUN UMAN          28/12/2016
# 185         ESTADOS UNIDOS  SANTO TOMAS DE CASTILLA          21/12/2016
# ...                    ...                      ...                 ...
# 12012                CHINA           PUERTO QUETZAL          12/12/2016
# 17623            TAILANDIA           PUERTO QUETZAL          22/12/2016
# 17624            TAILANDIA           PUERTO QUETZAL          22/12/2016
# 17626            INDONESIA           PUERTO QUETZAL          22/12/2016
# 7489                 JAPON           PUERTO QUETZAL          15/12/2016
#
#        Partida Arancelaria  Modelo_del_Vehiculo       Marca  \
# ...

# %% [markdown]
# # Comparación del año de los modelos de los carros en el año 2016

# %%
Mviejos2016 = len(ene2016[ene2016.Modelo_del_Vehiculo == 1900])
año = 1939
while año < 2010:
    Mviejos2016 = Mviejos2016 + len(ene2016[ene2016.Modelo_del_Vehiculo == año])
    año += 1

viejos2016 = len(ene2016[ene2016.Modelo_del_Vehiculo == 2010])
añoViejo = 2011
while añoViejo < 2014:
    viejos2016 = viejos2016 + len(ene2016[ene2016.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2016 = len(ene2016[ene2016.Modelo_del_Vehiculo == 2015])
añoNuevo = 2016
while añoNuevo < 2017:
    nuevos2016 = nuevos2016 + len(ene2016[ene2016.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2016 = Mviejos2016 + len(feb2016[feb2016.Modelo_del_Vehiculo == 1954])
año = 1955
while año < 2010:
    Mviejos2016 = Mviejos2016 + len(feb2016[feb2016.Modelo_del_Vehiculo == año])
    año += 1

viejos2016 = viejos2016 + len(feb2016[feb2016.Modelo_del_Vehiculo == 2010])
añoViejo = 2011
while añoViejo < 2014:
    viejos2016 = viejos2016 + len(feb2016[ene2016.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2016 = nuevos2016 + len(feb2016[feb2016.Modelo_del_Vehiculo == 2015])
añoNuevo = 2016
while añoNuevo < 2017:
    nuevos2016 = nuevos2016 + len(feb2016[feb2016.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1
# Out:
# c:\users\axelt\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.

# %%
Mviejos2016 = Mviejos2016 + len(mar2016[mar2016.Modelo_del_Vehiculo == 1942])
año = 1943
while año < 2010:
    Mviejos2016 = Mviejos2016 + len(mar2016[mar2016.Modelo_del_Vehiculo == año])
    año += 1

viejos2016 = viejos2016 + len(mar2016[mar2016.Modelo_del_Vehiculo == 2010])
añoViejo = 2011
while añoViejo < 2014:
    viejos2016 = viejos2016 + len(mar2016[mar2016.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2016 = nuevos2016 + len(mar2016[mar2016.Modelo_del_Vehiculo == 2015])
añoNuevo = 2016
while añoNuevo < 2017:
    nuevos2016 = nuevos2016 + len(mar2016[mar2016.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2016 = Mviejos2016 + len(may2016[may2016.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2010:
    Mviejos2016 = Mviejos2016 + len(may2016[may2016.Modelo_del_Vehiculo == año])
    año += 1

viejos2016 = viejos2016 + len(may2016[may2016.Modelo_del_Vehiculo == 2010])
añoViejo = 2011
while añoViejo < 2014:
    viejos2016 = viejos2016 + len(may2016[may2016.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2016 = nuevos2016 + len(may2016[may2016.Modelo_del_Vehiculo == 2015])
añoNuevo = 2016
while añoNuevo < 2017:
    nuevos2016 = nuevos2016 + len(may2016[may2016.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2016 = Mviejos2016 + len(jun2016[jun2016.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2010:
    Mviejos2016 = Mviejos2016 + len(jun2016[jun2016.Modelo_del_Vehiculo == año])
    año += 1

viejos2016 = viejos2016 + len(jun2016[jun2016.Modelo_del_Vehiculo == 2010])
añoViejo = 2011
while añoViejo < 2014:
    viejos2016 = viejos2016 + len(jun2016[jun2016.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2016 = nuevos2016 + len(jun2016[jun2016.Modelo_del_Vehiculo == 2015])
añoNuevo = 2016
while añoNuevo < 2017:
    nuevos2016 = nuevos2016 + len(jun2016[jun2016.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2016 = Mviejos2016 + len(jul2016[jul2016.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2010:
    Mviejos2016 = Mviejos2016 + len(jul2016[jul2016.Modelo_del_Vehiculo == año])
    año += 1

viejos2016 = viejos2016 + len(jul2016[jul2016.Modelo_del_Vehiculo == 2010])
añoViejo = 2011
while añoViejo < 2014:
    viejos2016 = viejos2016 + len(jul2016[jul2016.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2016 = nuevos2016 + len(jul2016[jul2016.Modelo_del_Vehiculo == 2015])
añoNuevo = 2016
while añoNuevo < 2017:
    nuevos2016 = nuevos2016 + len(jul2016[jul2016.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2016 = Mviejos2016 + len(oct2016[oct2016.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2010:
    Mviejos2016 = Mviejos2016 + len(oct2016[oct2016.Modelo_del_Vehiculo == año])
    año += 1

viejos2016 = viejos2016 + len(oct2016[oct2016.Modelo_del_Vehiculo == 2010])
añoViejo = 2011
while añoViejo < 2014:
    viejos2016 = viejos2016 + len(oct2016[oct2016.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2016 = nuevos2016 + len(oct2016[oct2016.Modelo_del_Vehiculo == 2015])
añoNuevo = 2016
while añoNuevo < 2017:
    nuevos2016 = nuevos2016 + len(oct2016[oct2016.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2016 = Mviejos2016 + len(dic2016[dic2016.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2010:
    Mviejos2016 = Mviejos2016 + len(dic2016[dic2016.Modelo_del_Vehiculo == año])
    año += 1

viejos2016 = viejos2016 + len(dic2016[dic2016.Modelo_del_Vehiculo == 2010])
añoViejo = 2011
while añoViejo < 2014:
    viejos2016 = viejos2016 + len(dic2016[dic2016.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2016 = nuevos2016 + len(dic2016[dic2016.Modelo_del_Vehiculo == 2015])
añoNuevo = 2016
while añoNuevo < 2017:
    nuevos2016 = nuevos2016 + len(dic2016[dic2016.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
años2016 = [Mviejos2016,viejos2016,nuevos2016]
nombres = ["Modelos muy viejos","Modelos viejos","Modelos nuevos"]
plt.pie(años2016, labels=nombres)
plt.show()

# %% [markdown]
# # Comparación del año de los modelos de los carros en el año 2017

# %%
ene2017 = pd.read_csv('2017\Enero2017.csv')
feb2017 = pd.read_csv('2017\Febrero2017.csv')
mar2017 = pd.read_csv('2017\Marzo2017.csv')
abr2017 = pd.read_csv('2017\Abril2017.csv')
may2017 = pd.read_csv('2017\Mayo2017.csv')
jun2017 = pd.read_csv('2017\Junio2017.csv')
jul2017 = pd.read_csv('2017\Julio2017.csv')
ago2017 = pd.read_csv('2017\Agosto2017.csv')
sep2017 = pd.read_csv('2017\Septiembre2017.csv')
oct2017 = pd.read_csv('2017\Octubre2017.csv')
nov2017 = pd.read_csv('2017\_Noviembre2017.csv')
dic2017 = pd.read_csv('2017\Diciembre2017.csv')
dic2017.sort_values(by ='Modelo_del_Vehiculo', ascending=True)
#procedemos a realizar el mismo proceso pero con el año 2017
# Out:
#       Pais_de_Proveniencia Aduana de Ingreso  Fecha de la Poliza  \
# 7002        ESTADOS UNIDOS        TECUN UMAN          12/12/2017
# 24648       ESTADOS UNIDOS        TECUN UMAN          19/12/2017
# 24842       ESTADOS UNIDOS        TECUN UMAN          27/12/2017
# 7554        ESTADOS UNIDOS         EL CARMEN          13/12/2017
# 11561       ESTADOS UNIDOS        TECUN UMAN          27/12/2017
# ...                    ...               ...                 ...
# 21979                CHINA    PUERTO QUETZAL          19/12/2017
# 21978                CHINA    PUERTO QUETZAL          19/12/2017
# 21977                CHINA    PUERTO QUETZAL          19/12/2017
# 21995                CHINA    PUERTO QUETZAL          22/12/2017
# 18461                CHINA    PUERTO QUETZAL          20/12/2017
#
#        Partida Arancelaria  Modelo_del_Vehiculo     Marca        Linea  \
# 7002            8701910000                 1900    KUBOTA       M9540D
# ...

# %%
Mviejos2017 = len(ene2017[ene2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(ene2017[ene2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = len(ene2017[ene2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(ene2017[ene2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = len(ene2017[ene2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(ene2017[ene2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(feb2017[feb2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(feb2017[feb2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(feb2017[feb2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(feb2017[ene2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(feb2017[feb2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(feb2017[feb2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(mar2017[mar2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(mar2017[mar2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(mar2017[mar2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(mar2017[mar2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(mar2017[mar2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(mar2017[mar2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(abr2017[abr2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(abr2017[abr2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(abr2017[abr2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(abr2017[abr2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(abr2017[abr2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(abr2017[abr2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(may2017[may2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(may2017[may2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(may2017[may2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(may2017[may2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(may2017[may2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(may2017[may2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(jun2017[jun2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(jun2017[jun2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(jun2017[jun2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(jun2017[jun2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(jun2017[jun2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(jun2017[jun2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(jul2017[jul2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(jul2017[jul2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(jul2017[jul2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(jul2017[jul2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(jul2017[jul2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(jul2017[jul2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(ago2017[ago2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(ago2017[ago2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(ago2017[ago2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(ago2017[ago2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(ago2017[ago2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(ago2017[ago2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(sep2017[sep2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(sep2017[sep2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(sep2017[sep2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(sep2017[sep2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(sep2017[sep2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(sep2017[sep2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(oct2017[oct2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(oct2017[oct2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(oct2017[oct2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(oct2017[oct2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(oct2017[oct2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(oct2017[oct2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(nov2017[nov2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(nov2017[nov2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(nov2017[nov2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(nov2017[nov2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(nov2017[nov2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(nov2017[nov2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2017 = Mviejos2017 + len(dic2017[dic2017.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2011:
    Mviejos2017 = Mviejos2017 + len(dic2017[dic2017.Modelo_del_Vehiculo == año])
    año += 1

viejos2017 = viejos2017 + len(dic2017[dic2017.Modelo_del_Vehiculo == 2011])
añoViejo = 2012
while añoViejo < 2015:
    viejos2017 = viejos2017 + len(dic2017[dic2017.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2017 = nuevos2017 + len(dic2017[dic2017.Modelo_del_Vehiculo == 2016])
añoNuevo = 2017
while añoNuevo < 2018:
    nuevos2017 = nuevos2017 + len(dic2017[dic2017.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
años2017 = [Mviejos2017,viejos2017,nuevos2017]
nombres = ["Modelos muy viejos","Modelos viejos","Modelos nuevos"]
plt.pie(años2017, labels=nombres)
plt.show()

# %% [markdown]
# # Comparación del año de los modelos de los carros en el año 2018

# %%
ene2018 = pd.read_csv('2018\Enero2018.csv')
feb2018 = pd.read_csv('2018\Febrero2018.csv')
mar2018 = pd.read_csv('2018\Marzo2018.csv')
abr2018 = pd.read_csv('2018\Abril2018.csv')
may2018 = pd.read_csv('2018\Mayo2018.csv')
jun2018 = pd.read_csv('2018\Junio2018.csv')
jul2018 = pd.read_csv('2018\Julio2018.csv')
ago2018 = pd.read_csv('2018\Agosto2018.csv')
sep2018 = pd.read_csv('2018\Septiembre2018.csv')
oct2018 = pd.read_csv('2018\Octubre2018.csv')
nov2018 = pd.read_csv('2018\_Noviembre2018.csv')
dic2018 = pd.read_csv('2018\Diciembre2018.csv')
dic2018.sort_values(by ='Modelo_del_Vehiculo', ascending=True)
#procedemos a realizar el mismo proceso pero con el año 2017
# Out:
#       Pais_de_Proveniencia Aduana de Ingreso  Fecha de la Poliza  \
# 11737                JAPON    PUERTO QUETZAL          11/12/2018
# 2098        ESTADOS UNIDOS         EL CARMEN          16/12/2018
# 1929        ESTADOS UNIDOS         EL CARMEN          16/12/2018
# 11749                JAPON    PUERTO QUETZAL          11/12/2018
# 19850       ESTADOS UNIDOS         EL CARMEN          16/12/2018
# ...                    ...               ...                 ...
# 5792             INDONESIA    PUERTO QUETZAL          18/12/2018
# 5791             INDONESIA    PUERTO QUETZAL          18/12/2018
# 5788             INDONESIA    PUERTO QUETZAL          18/12/2018
# 5804             INDONESIA    PUERTO QUETZAL          18/12/2018
# 5789             INDONESIA    PUERTO QUETZAL          18/12/2018
#
#        Partida Arancelaria  Modelo_del_Vehiculo    Marca  \
# 11737           8711209000                 1900    HONDA
# 2098            8703100000                 1900  KINROAD
# ...

# %%
Mviejos2018 = len(ene2018[ene2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(ene2018[ene2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = len(ene2018[ene2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(ene2018[ene2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = len(ene2018[ene2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(ene2018[ene2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(feb2018[feb2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(feb2018[feb2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(feb2018[feb2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(feb2018[ene2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(feb2018[feb2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(feb2018[feb2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1
# Out:
# c:\users\axelt\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.

# %%
Mviejos2018 = Mviejos2018 + len(mar2018[mar2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(mar2018[mar2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(mar2018[mar2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(mar2018[mar2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(mar2018[mar2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(mar2018[mar2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(abr2018[abr2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(abr2018[abr2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(abr2018[abr2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(abr2018[abr2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(abr2018[abr2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(abr2018[abr2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(may2018[may2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(may2018[may2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(may2018[may2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(may2018[may2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(may2018[may2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(may2018[may2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(jun2018[jun2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(jun2018[jun2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(jun2018[jun2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(jun2018[jun2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(jun2018[jun2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(jun2018[jun2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(jul2018[jul2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(jul2018[jul2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(jul2018[jul2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(jul2018[jul2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(jul2018[jul2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(jul2018[jul2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(ago2018[ago2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(ago2018[ago2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(ago2018[ago2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(ago2018[ago2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(ago2018[ago2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(ago2018[ago2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(sep2018[sep2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(sep2018[sep2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(sep2018[sep2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(sep2018[sep2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(sep2018[sep2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(sep2018[sep2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(oct2018[oct2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(oct2018[oct2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(oct2018[oct2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(oct2018[oct2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(oct2018[oct2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(oct2018[oct2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(nov2018[nov2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(nov2018[nov2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(nov2018[nov2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(nov2018[nov2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(nov2018[nov2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(nov2018[nov2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2018 = Mviejos2018 + len(dic2018[dic2018.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2012:
    Mviejos2018 = Mviejos2018 + len(dic2018[dic2018.Modelo_del_Vehiculo == año])
    año += 1

viejos2018 = viejos2018 + len(dic2018[dic2018.Modelo_del_Vehiculo == 2012])
añoViejo = 2013
while añoViejo < 2016:
    viejos2018 = viejos2018 + len(dic2018[dic2018.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2018 = nuevos2018 + len(dic2018[dic2018.Modelo_del_Vehiculo == 2017])
añoNuevo = 2018
while añoNuevo < 2019:
    nuevos2018 = nuevos2018 + len(dic2018[dic2018.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
años2018 = [Mviejos2018,viejos2018,nuevos2018]
nombres = ["Modelos muy viejos","Modelos viejos","Modelos nuevos"]
plt.pie(años2018, labels=nombres)
plt.show()

# %% [markdown]
# # Comparación del año de los modelos de los carros en el año 2019

# %%
ene2019 = pd.read_csv('2019\Enero2019.csv')
feb2019 = pd.read_csv('2019\Febrero2019.csv')
mar2019 = pd.read_csv('2019\Marzo2019.csv')
abr2019 = pd.read_csv('2019\Abril2019.csv')
may2019 = pd.read_csv('2019\Mayo2019.csv')
jun2019 = pd.read_csv('2019\Junio2019.csv')
jul2019 = pd.read_csv('2019\Julio2019.csv')
ago2019 = pd.read_csv('2019\Agosto2019.csv')
sep2019 = pd.read_csv('2019\Septiembre2019.csv')
nov2019 = pd.read_csv('2019\_Noviembre2019.csv')
dic2019 = pd.read_csv('2019\Diciembre2019.csv')
dic2019.sort_values(by ='Modelo_del_Vehiculo', ascending=True)
#procedemos a realizar el mismo proceso pero con el año 2017
# Out:
#       Pais_de_Proveniencia Aduana de Ingreso  Fecha de la Poliza  \
# 13681                JAPON        TECUN UMAN          17/12/2019
# 36219       ESTADOS UNIDOS    PUERTO BARRIOS          04/01/2020
# 32496   ALEMANIA REP. FED.        TECUN UMAN          04/01/2020
# 4340        ESTADOS UNIDOS        TECUN UMAN          16/12/2019
# 32026       ESTADOS UNIDOS        TECUN UMAN          27/12/2019
# ...                    ...               ...                 ...
# 8951             TAILANDIA    PUERTO QUETZAL          07/01/2020
# 25154                CHINA    PUERTO QUETZAL          06/01/2020
# 25155                CHINA    PUERTO QUETZAL          06/01/2020
# 8954             TAILANDIA    PUERTO QUETZAL          07/01/2020
# 9401             TAILANDIA    PUERTO QUETZAL          07/01/2020
#
#        Partida Arancelaria  Modelo_del_Vehiculo            Marca  \
# 13681           8704315100                 1900           TOYOTA
# ...

# %%
Mviejos2019 = len(ene2019[ene2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(ene2019[ene2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = len(ene2019[ene2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(ene2019[ene2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = len(ene2019[ene2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(ene2019[ene2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(feb2019[feb2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(feb2019[feb2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(feb2019[feb2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(feb2019[feb2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(feb2019[feb2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(feb2019[feb2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(mar2019[mar2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(mar2019[mar2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(mar2019[mar2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(mar2019[mar2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(mar2019[mar2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(mar2019[mar2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(abr2019[abr2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(abr2019[abr2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(abr2019[abr2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(abr2019[abr2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(abr2019[abr2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(abr2019[abr2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(may2019[may2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(may2019[may2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(may2019[may2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(may2019[may2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(may2019[may2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(may2019[may2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(jun2019[jun2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(jun2019[jun2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(jun2019[jun2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(jun2019[jun2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(jun2019[jun2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(jun2019[jun2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(jul2019[jul2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(jul2019[jul2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(jul2019[jul2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(jul2019[jul2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(jul2019[jul2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(jul2019[jul2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(ago2019[ago2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(ago2019[ago2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(ago2019[ago2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(ago2019[ago2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(ago2019[ago2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(ago2019[ago2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(sep2019[sep2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(sep2019[sep2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(sep2019[sep2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(sep2019[sep2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(sep2019[sep2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(sep2019[sep2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(nov2019[nov2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(nov2019[nov2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(nov2019[nov2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(nov2019[nov2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(nov2019[nov2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(nov2019[nov2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
Mviejos2019 = Mviejos2019 + len(dic2019[dic2019.Modelo_del_Vehiculo == 1900])
año = 1901
while año < 2013:
    Mviejos2019 = Mviejos2019 + len(dic2019[dic2019.Modelo_del_Vehiculo == año])
    año += 1

viejos2019 = viejos2019 + len(dic2019[dic2019.Modelo_del_Vehiculo == 2013])
añoViejo = 2014
while añoViejo < 2017:
    viejos2019 = viejos2019 + len(dic2019[dic2019.Modelo_del_Vehiculo == añoViejo])
    añoViejo += 1

nuevos2019 = nuevos2019 + len(dic2019[dic2019.Modelo_del_Vehiculo == 2018])
añoNuevo = 2019
while añoNuevo < 2020:
    nuevos2019 = nuevos2019 + len(dic2019[dic2019.Modelo_del_Vehiculo == añoNuevo])
    añoNuevo += 1

# %%
años2019 = [Mviejos2019,viejos2019,nuevos2019]
nombres = ["Modelos muy viejos","Modelos viejos","Modelos nuevos"]
plt.pie(años2019, labels=nombres)
plt.show()
