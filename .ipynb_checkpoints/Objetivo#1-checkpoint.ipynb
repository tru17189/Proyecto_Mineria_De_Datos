# %%
# Librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # ¿De qué países se están importando más vehículos? 2016

# %%
#Primero Vamos a saber de cuantos paises estamos importados de este mes para comenzar
ene2016 = pd.read_csv('2016\Enero2016.csv')
ene = ene2016.groupby('pais').count()
ene2016.groupby('pais').count()
#con esta tabla podemos observar que hay una gran cantidad de paises de los que estamos importando carros, pero
#en algunos se importan una cantidad demasiado pequeña, en algunos se importa incluso un carro, asi que para este
#trabajo solo tomaremos los 5 paises de los que mas estamos importando carros en general de todos lo meses.
# Out:
#                     Pais_de_Proveniencia  Aduana de Ingreso  \
# pais
# ALEMANIA REP. FED.                   195                195
# ARGENTINA                              2                  2
# AUSTRALIA                              1                  1
# AUSTRIA                                2                  2
# BELGICA                                3                  3
# BELICE                                 1                  1
# BRASIL                                73                 73
# CANADA                               401                401
# CHINA                               8692               8692
# COLOMBIA                               3                  3
# COREA DEL SUR                        971                971
# ESPANA                                 7                  7
# ESTADOS UNIDOS                      4955               4955
# FRANCIA                               27                 27
# ...

# %%
#A continuacion presentare los 5 paises de los que mas importamos de cada mes del 2016, despues guardaremos
#la cantidad total de los 5 que mas aparecieron para hacer una grafica. 
ene = ene.sort_values(by ='Marca', ascending=False)
ene.head(6)
# Out:
#                 Pais_de_Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           8692               8692                 8692
# ESTADOS UNIDOS                  4955               4955                 4955
# JAPON                           3336               3336                 3336
# INDIA                           1292               1292                 1292
# COREA DEL SUR                    971                971                  971
# CANADA                           401                401                  401
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          8692                 8692   8692   8692
# ESTADOS UNIDOS                 4955                 4955   4955   4955
# JAPON                          3336                 3336   3336   3336
# INDIA                          1292                 1292   1292   1292
# ...

# %%
china = 8692
usa = 4955
japon = 3336
india = 1292
coreaS = 971
canada = 401

# %%
feb2016 = pd.read_csv('2016\Febrero2016.csv')
feb = feb2016.groupby('pais').count()
feb = feb.sort_values(by ='Marca', ascending=False)
feb.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# ESTADOS UNIDOS                  6366               6366                 6366
# CHINA                           5101               5101                 5101
# JAPON                           3951               3951                 3951
# INDIA                           1793               1793                 1793
# COREA DEL SUR                    580                580                  580
# CANADA                           513                513                  513
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# ESTADOS UNIDOS                 6366                 6366   6366   6366
# CHINA                          5101                 5101   5101   5101
# JAPON                          3951                 3951   3951   3951
# INDIA                          1793                 1793   1793   1793
# ...

# %%
usa = usa + 6366
china = china + 5101
japon = japon + 3951
india = india + 1793
coreaS = coreaS + 580 
canada = canada + 513

# %%
mar2016 = pd.read_csv('2016\Marzo2016.csv')
mar = mar2016.groupby('pais').count()
mar = mar.sort_values(by ='Marca', ascending=False)
mar.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           7357               7357                 7357
# ESTADOS UNIDOS                  6204               6204                 6204
# JAPON                           4314               4314                 4314
# INDIA                           3747               3747                 3747
# COREA DEL SUR                    997                997                  997
# CANADA                           575                575                  575
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          7357                 7357   7357   7357
# ESTADOS UNIDOS                 6204                 6204   6204   6204
# JAPON                          4314                 4314   4314   4314
# INDIA                          3747                 3747   3747   3747
# ...

# %%
china = china + 7357
usa = usa + 6204
japon = japon + 4314
india = india + 3747
coreaS = coreaS + 997
canada = canada + 575

# %%
may2016 = pd.read_csv('2016\Mayo2016.csv')
may = may2016.groupby('pais').count()
may = may.sort_values(by ='Marca', ascending=False)
may.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           8386               8386                 8386
# JAPON                           5755               5755                 5755
# ESTADOS UNIDOS                  3517               3517                 3517
# INDIA                           2967               2967                 2967
# CANADA                          1174               1174                 1174
# COREA DEL SUR                   1036               1036                 1036
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          8386                 8386   8386   8386
# JAPON                          5755                 5755   5755   5755
# ESTADOS UNIDOS                 3517                 3517   3517   3517
# INDIA                          2967                 2967   2967   2967
# ...

# %%
china = china + 8386
japon = japon + 5755
usa = usa + 3517
india = india + 2967
canada = canada + 1174
coreaS = coreaS + 1036

# %%
jun2016 = pd.read_csv('2016\Junio2016.csv')
jun = jun2016.groupby('pais').count()
jun = jun.sort_values(by ='Marca', ascending=False)
jun.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          12888              12888                12888
# JAPON                           5759               5759                 5759
# INDIA                           3655               3655                 3655
# ESTADOS UNIDOS                  3035               3035                 3035
# COREA DEL SUR                   1426               1426                 1426
# CANADA                          1118               1118                 1118
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         12888                12888  12888  12888
# JAPON                          5759                 5759   5759   5759
# INDIA                          3655                 3655   3655   3655
# ESTADOS UNIDOS                 3035                 3035   3035   3035
# ...

# %%
china = china + 12888
japon = japon + 5759
india = india + 3655
usa = usa + 3035
coreaS = coreaS + 1426
canada = canada + 1118

# %%
jul2016 = pd.read_csv('2016\Julio2016.csv')
jul = jul2016.groupby('pais').count()
jul = jul.sort_values(by ='Marca', ascending=False)
jul.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           7765               7765                 7765
# JAPON                           6015               6015                 6015
# ESTADOS UNIDOS                  3434               3434                 3434
# INDIA                           2479               2479                 2479
# CANADA                          1208               1208                 1208
# COREA DEL SUR                    974                974                  974
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          7765                 7765   7765   7765
# JAPON                          6015                 6015   6015   6015
# ESTADOS UNIDOS                 3434                 3434   3434   3434
# INDIA                          2479                 2479   2479   2479
# ...

# %%
china = china + 7765
japon = japon + 6015
usa = usa + 3434
india = india + 2479
canada = canada + 1208
coreaS = coreaS + 974

# %%
ago2016 = pd.read_csv('2016\Agosto2016.csv')
ago = ago2016.groupby('pais').count()
ago = ago.sort_values(by ='Marca', ascending=False)
ago.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          12571              12571                12571
# JAPON                           5971               5971                 5971
# INDIA                           3821               3821                 3821
# ESTADOS UNIDOS                  3353               3353                 3353
# COREA DEL SUR                   1183               1183                 1183
# CANADA                          1144               1144                 1144
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         12571                12571  12571  12571
# JAPON                          5971                 5971   5971   5971
# INDIA                          3821                 3821   3821   3821
# ESTADOS UNIDOS                 3353                 3353   3353   3353
# ...

# %%
china = china + 12571
japon = japon + 5971
india = india + 3821
usa = usa + 3353
coreaS = coreaS + 1183
canada = canada + 1144

# %%
oct2016 = pd.read_csv('2016\Octubre2016.csv')
oct = oct2016.groupby('pais').count()
oct = oct.sort_values(by ='Marca', ascending=False)
oct.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           6854               6854                 6854
# JAPON                           6450               6450                 6450
# ESTADOS UNIDOS                  3839               3839                 3839
# INDIA                           2006               2006                 2006
# CANADA                          1080               1080                 1080
# COREA DEL SUR                   1036               1036                 1036
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          6854                 6854   6854   6854
# JAPON                          6450                 6450   6450   6450
# ESTADOS UNIDOS                 3839                 3839   3839   3839
# INDIA                          2006                 2006   2006   2006
# ...

# %%
china = china + 6854
japon = japon + 6450
usa = usa + 3839
india = india + 2006
canada = canada + 1080
coreaS = coreaS + 1036

# %%
dic2016 = pd.read_csv('2016\Diciembre2016.csv')
dic = dic2016.groupby('pais').count()
dic = dic.sort_values(by ='Marca', ascending=False)
dic.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           8627               8627                 8627
# JAPON                           7016               7016                 7016
# ESTADOS UNIDOS                  4517               4517                 4517
# INDIA                           1955               1955                 1955
# CANADA                          1261               1261                 1261
# COREA DEL SUR                   1036               1036                 1036
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          8627                 8627   8627   8627
# JAPON                          7016                 7016   7016   7016
# ESTADOS UNIDOS                 4517                 4517   4517   4517
# INDIA                          1955                 1955   1955   1955
# ...

# %%
china = china + 8627
japon = japon + 7016
usa = usa + 4517
india = india + 1955
canada = canada + 1261
coreaS = coreaS + 1036

# %%
paises2016 = [china,japon,india,usa,coreaS]
nombres = ["China","Japon","India","USA","Corea del sur"]
plt.pie(paises2016, labels=nombres)
plt.show()

# %% [markdown]
# # ¿De qué países se están importando más vehículos? 2017

# %%
feb2017 = pd.read_csv('2017\Febrero2017.csv')
feb2 = feb2017.groupby('pais').count()
feb2 = feb2.sort_values(by ='Marca', ascending=False)
feb2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# JAPON                           6007               6007                 6007
# CHINA                           5176               5176                 5176
# ESTADOS UNIDOS                  3467               3467                 3467
# INDIA                           1435               1435                 1435
# CANADA                          1115               1115                 1115
# COREA DEL SUR                   1084               1084                 1084
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# JAPON                          6007                 6007   6007   6007
# CHINA                          5176                 5176   5176   5176
# ESTADOS UNIDOS                 3467                 3467   3467   3467
# INDIA                          1435                 1435   1435   1435
# ...

# %%
japon2 = 6007
china2 = 5176
usa2 = 3467
india2 = 1435
canada2 = 1115
coreaS2 = 1084

# %%
mar2017 = pd.read_csv('2017\Marzo2017.csv')
mar2 = mar2017.groupby('pais').count()
mar2 = mar2.sort_values(by ='Marca', ascending=False)
mar2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# JAPON                           7175               7175                 7175
# CHINA                           6270               6270                 6270
# ESTADOS UNIDOS                  4341               4341                 4341
# INDIA                           2100               2100                 2100
# CANADA                          1261               1261                 1261
# COREA DEL SUR                   1085               1085                 1085
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# JAPON                          7175                 7175   7175   7175
# CHINA                          6270                 6270   6270   6270
# ESTADOS UNIDOS                 4341                 4341   4341   4341
# INDIA                          2100                 2100   2100   2100
# ...

# %%
japon2 = japon2 + 7175
china2 = china2 + 6270
usa2 = usa2 + 4341
india2 = india2 + 2100
canada2 = canada2 + 1261
coreaS2 = coreaS2 + 1085

# %%
abr2017 = pd.read_csv('2017\Abril2017.csv')
abr2 = abr2017.groupby('pais').count()
abr2 = abr2.sort_values(by ='Marca', ascending=False)
abr2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           5999               5999                 5999
# JAPON                           4793               4793                 4793
# INDIA                           3779               3779                 3779
# ESTADOS UNIDOS                  3083               3083                 3083
# CANADA                           860                860                  860
# COREA DEL SUR                    855                855                  855
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          5999                 5999   5999   5999
# JAPON                          4793                 4793   4793   4793
# INDIA                          3779                 3779   3779   3779
# ESTADOS UNIDOS                 3083                 3083   3083   3083
# ...

# %%
china2 = china2 + 5999
japon2 = japon2 + 4793
india2 = india2 + 3779
usa2 = usa2 + 3083
canada2 = canada2 + 860
coreaS2 = coreaS2 + 855

# %%
may2017 = pd.read_csv('2017\Mayo2017.csv')
may2 = may2017.groupby('pais').count()
may2 = may2.sort_values(by ='Marca', ascending=False)
may2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           6287               6287                 6287
# JAPON                           5849               5849                 5849
# INDIA                           5475               5475                 5475
# ESTADOS UNIDOS                  3723               3723                 3723
# COREA DEL SUR                   1042               1042                 1042
# CANADA                          1013               1013                 1013
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          6287                 6287   6287   6287
# JAPON                          5849                 5849   5849   5849
# INDIA                          5475                 5475   5475   5475
# ESTADOS UNIDOS                 3723                 3723   3723   3723
# ...

# %%
china2 = china2 + 6287
japon2 = japon2 + 5849
india2 = india2 + 5475
usa2 = usa2 + 3723
coreaS2 = coreaS2 + 1042
canada2 = canada2 + 1013

# %%
jun2017 = pd.read_csv('2017\Junio2017.csv')
jun2 = jun2017.groupby('pais').count()
jun2 = jun2.sort_values(by ='Marca', ascending=False)
jun2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           9632               9632                 9632
# JAPON                           5990               5990                 5990
# INDIA                           5242               5242                 5242
# ESTADOS UNIDOS                  3435               3435                 3435
# COREA DEL SUR                   1045               1045                 1045
# CANADA                           969                969                  969
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          9632                 9632   9632   9632
# JAPON                          5990                 5990   5990   5990
# INDIA                          5242                 5242   5242   5242
# ESTADOS UNIDOS                 3435                 3435   3435   3435
# ...

# %%
china2 = china2 + 9632
japon2 = japon2 + 5990
india2 = india2 + 5242
usa2 = usa2 + 3435
coreaS2 = coreaS2 + 1045
canada2 = canada2 + 969

# %%
jul2017 = pd.read_csv('2017\Julio2017.csv')
jul2 = jul2017.groupby('pais').count()
jul2 = jul2.sort_values(by ='Marca', ascending=False)
jul2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          12696              12696                12696
# INDIA                           6644               6644                 6644
# JAPON                           5785               5785                 5785
# ESTADOS UNIDOS                  3613               3613                 3613
# CANADA                          1021               1021                 1021
# COREA DEL SUR                    840                840                  840
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         12696                12696  12696  12696
# INDIA                          6644                 6644   6644   6644
# JAPON                          5785                 5785   5785   5785
# ESTADOS UNIDOS                 3613                 3613   3613   3613
# ...

# %%
china2 = china2 + 12696
india2 = india2 + 6644
japon2 = japon2 + 5785
usa2 = usa2 + 3613
canada2 = canada2 + 1021
coreaS2 = coreaS2 + 840

# %%
ago2017 = pd.read_csv('2017\Agosto2017.csv')
ago2 = ago2017.groupby('pais').count()
ago2 = ago2.sort_values(by ='Marca', ascending=False)
ago2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          12104              12104                12104
# INDIA                           7043               7043                 7043
# JAPON                           6380               6380                 6380
# ESTADOS UNIDOS                  3742               3742                 3742
# COREA DEL SUR                   1303               1303                 1303
# CANADA                          1052               1052                 1052
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         12104                12104  12104  12104
# INDIA                          7043                 7043   7043   7043
# JAPON                          6380                 6380   6380   6380
# ESTADOS UNIDOS                 3742                 3742   3742   3742
# ...

# %%
china2 = china2 + 12104
india2 = india2 + 7043
japon2 = japon2 + 6380
usa2 = usa2 + 3742
coreaS2 = coreaS2 + 1303
canada2 = canada2 + 1052

# %%
sep2017 = pd.read_csv('2017\Septiembre2017.csv')
sep2 = sep2017.groupby('pais').count()
sep2 = sep2.sort_values(by ='Marca', ascending=False)
sep2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           9815               9815                 9815
# INDIA                           6256               6256                 6256
# JAPON                           6074               6074                 6074
# ESTADOS UNIDOS                  3491               3491                 3491
# CANADA                          1064               1064                 1064
# COREA DEL SUR                    994                994                  994
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          9815                 9815   9815   9815
# INDIA                          6256                 6256   6256   6256
# JAPON                          6074                 6074   6074   6074
# ESTADOS UNIDOS                 3491                 3491   3491   3491
# ...

# %%
china2 = china2 + 9815
india2 = india2 + 6256
japon2 = japon2 + 6074
usa2 = usa2 + 3491
canada2 = canada2 + 1064
coreaS2 = coreaS2 + 994

# %%
oct2017 = pd.read_csv('2017\Octubre2017.csv')
oct2 = oct2017.groupby('pais').count()
oct2 = oct2.sort_values(by ='Marca', ascending=False)
oct2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          21228              21228                21228
# JAPON                           6670               6670                 6670
# INDIA                           5586               5586                 5586
# ESTADOS UNIDOS                  3971               3971                 3971
# COREA DEL SUR                   1194               1194                 1194
# CANADA                          1076               1076                 1076
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         21228                21228  21228  21228
# JAPON                          6670                 6670   6670   6670
# INDIA                          5586                 5586   5586   5586
# ESTADOS UNIDOS                 3971                 3971   3971   3971
# ...

# %%
china2 = china2 + 21228
japon2 = japon2 + 6670
india2 = india2 + 5586
usa2 = usa2 + 3971
coreaS2 = coreaS2 + 1194
canada2 = canada2 + 1076

# %%
nov2017 = pd.read_csv('2017\_Noviembre2017.csv')
nov2 = nov2017.groupby('pais').count()
nov2 = nov2.sort_values(by ='Marca', ascending=False)
nov2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          14288              14288                14288
# JAPON                           6663               6663                 6663
# INDIA                           5189               5189                 5189
# ESTADOS UNIDOS                  4019               4019                 4019
# CANADA                          1153               1153                 1153
# COREA DEL SUR                    886                886                  886
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         14288                14288  14288  14288
# JAPON                          6663                 6663   6663   6663
# INDIA                          5189                 5189   5189   5189
# ESTADOS UNIDOS                 4019                 4019   4019   4019
# ...

# %%
china2 = china2 + 14288
japon2 = japon2 + 6663
india2 = india2 + 5189
usa2 = usa2 + 4019
canada2 = canada2 + 1153
coreaS2 = coreaS2 + 886

# %%
dic2017 = pd.read_csv('2017\Diciembre2017.csv')
dic2 = dic2017.groupby('pais').count()
dic2 = dic2.sort_values(by ='Marca', ascending=False)
dic2.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          13901              13901                13901
# INDIA                           7053               7053                 7053
# JAPON                           7040               7040                 7040
# ESTADOS UNIDOS                  4803               4803                 4803
# COREA DEL SUR                   1143               1143                 1143
# CANADA                          1085               1085                 1085
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         13901                13901  13901  13901
# INDIA                          7053                 7053   7053   7053
# JAPON                          7040                 7040   7040   7040
# ESTADOS UNIDOS                 4803                 4803   4803   4803
# ...

# %%
china2 = china2 + 13901
india2 = india2 + 7053
japon2 = japon2 + 7040
usa2 = usa2 + 4803
coreaS2 = coreaS2 + 1143
canada2 = canada2 + 1085

# %%
paises2017 = [china2,japon2,india2,usa2,canada2]
nombres = ["China","Japon","India","USA","Canada"]
plt.pie(paises2017, labels=nombres)
plt.show()

# %% [markdown]
# # ¿De qué países se están importando más vehículos? 2018

# %%
ene2018 = pd.read_csv('2018\Enero2018.csv')
ene3 = ene2018.groupby('pais').count()
ene3 = ene3.sort_values(by ='Marca', ascending=False)
ene3.head(6)
# Out:
#                 Puerto  Pais de Proveniencia  Aduana de Ingreso  \
# pais
# CHINA            11293                 11293              11293
# INDIA             6828                  6828               6828
# JAPON             5333                  5333               5333
# ESTADOS UNIDOS    2688                  2688               2688
# COREA DEL SUR     1029                  1029               1029
# CANADA             918                   918                918
#
#                  Fecha de la Poliza  Partida Arancelaria  Modelo del Vehiculo  \
# pais
# CHINA                         11293                11293                11293
# INDIA                          6828                 6828                 6828
# JAPON                          5333                 5333                 5333
# ESTADOS UNIDOS                 2688                 2688                 2688
# COREA DEL SUR                  1029                 1029                 1029
# ...

# %%
china3 = 11293
india3 = 6828
japon3 = 5333
usa3 = 2688
coreaS3 = 1029
canada3 = 918

# %%
feb2018 = pd.read_csv('2018\Febrero2018.csv')
feb3 = feb2018.groupby('pais').count()
feb3 = feb3.sort_values(by ='Marca', ascending=False)
feb3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           6324               6324                 6324
# JAPON                           5599               5599                 5599
# ESTADOS UNIDOS                  2980               2980                 2980
# INDIA                           2910               2910                 2910
# COREA DEL SUR                    944                944                  944
# CANADA                           890                890                  890
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          6324                 6324   6324   6324
# JAPON                          5599                 5599   5599   5599
# ESTADOS UNIDOS                 2980                 2980   2980   2980
# INDIA                          2910                 2910   2910   2910
# ...

# %%
china3 = china3 + 6324
japon3 = japon3 + 5599
usa3 = usa3 + 2980
india3 = india3 + 2910
coreaS3 = coreaS3 + 944
canada3 = canada3 + 890

# %%
mar2018 = pd.read_csv('2018\Marzo2018.csv')
mar3 = mar2018.groupby('pais').count()
mar3 = mar3.sort_values(by ='Marca', ascending=False)
mar3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# INDIA                           7530               7530                 7530
# JAPON                           6378               6378                 6378
# CHINA                           5750               5750                 5750
# ESTADOS UNIDOS                  3711               3711                 3711
# COREA DEL SUR                   1319               1319                 1319
# CANADA                           940                940                  940
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# INDIA                          7530                 7530   7530   7530
# JAPON                          6378                 6378   6378   6378
# CHINA                          5750                 5750   5750   5750
# ESTADOS UNIDOS                 3711                 3711   3711   3711
# ...

# %%
india3 = india3 + 7530
japon3 = japon3 + 6378
china3 = china3 + 5750
usa3 = usa3 + 3711
coreaS3 = coreaS3 + 1319
canada3 = canada3 + 940

# %%
abr2018 = pd.read_csv('2018\Abril2018.csv')
abr3 = abr2018.groupby('pais').count()
abr3 = abr3.sort_values(by ='Marca', ascending=False)
abr3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          11040              11040                11040
# INDIA                           6248               6248                 6248
# JAPON                           5111               5111                 5111
# ESTADOS UNIDOS                  2841               2841                 2841
# COREA DEL SUR                    858                858                  858
# CANADA                           803                803                  803
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         11040                11040  11040  11040
# INDIA                          6248                 6248   6248   6248
# JAPON                          5111                 5111   5111   5111
# ESTADOS UNIDOS                 2841                 2841   2841   2841
# ...

# %%
china3 = china3 + 11040
india3 = india3 + 6248
japon3 = japon3 + 5111
usa3 = usa3 + 2841
coreaS3 = coreaS3 + 858
canada3 = canada3 + 803

# %%
may2018 = pd.read_csv('2018\Mayo2018.csv')
may3 = may2018.groupby('pais').count()
may3 = may3.sort_values(by ='Marca', ascending=False)
may3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           8266               8266                 8266
# INDIA                           5654               5654                 5654
# JAPON                           5619               5619                 5619
# ESTADOS UNIDOS                  3245               3245                 3245
# COREA DEL SUR                   1009               1009                 1009
# CANADA                           901                901                  901
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          8266                 8266   8266   8266
# INDIA                          5654                 5654   5654   5654
# JAPON                          5619                 5619   5619   5619
# ESTADOS UNIDOS                 3245                 3245   3245   3245
# ...

# %%
china3 = china3 + 8266
india3 = india3 + 5654
japon3 = japon3 + 5619
usa3 = usa3 + 3245
coreaS3 = coreaS3 + 1009
canada3 = canada3 + 901

# %%
jun2018 = pd.read_csv('2018\Junio2018.csv')
jun3 = jun2018.groupby('pais').count()
jun3 = jun3.sort_values(by ='Marca', ascending=False)
jun3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           8966               8966                 8966
# JAPON                           5481               5481                 5481
# ESTADOS UNIDOS                  3279               3279                 3279
# INDIA                           2815               2815                 2815
# COREA DEL SUR                    953                953                  953
# CANADA                           863                863                  863
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          8966                 8966   8966   8966
# JAPON                          5481                 5481   5481   5481
# ESTADOS UNIDOS                 3279                 3279   3279   3279
# INDIA                          2815                 2815   2815   2815
# ...

# %%
china3 = china3 + 8966
japon3 = japon3 + 5481
usa3 = usa3 + 3279
india3 = india3 + 2815
coreaS3 = coreaS3 + 953
canada3 = canada3 + 863

# %%
jul2018 = pd.read_csv('2018\Julio2018.csv')
jul3 = jul2018.groupby('pais').count()
jul3 = jul3.sort_values(by ='Marca', ascending=False)
jul3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           8845               8845                 8845
# JAPON                           5077               5077                 5077
# INDIA                           4431               4431                 4431
# ESTADOS UNIDOS                  3101               3101                 3101
# COREA DEL SUR                   1126               1126                 1126
# CANADA                           785                785                  785
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          8845                 8845   8845   8845
# JAPON                          5077                 5077   5077   5077
# INDIA                          4431                 4431   4431   4431
# ESTADOS UNIDOS                 3101                 3101   3101   3101
# ...

# %%
china3 = china3 + 8845
japon3 = japon3 + 5077
india3 = india3 + 4431
usa3 = usa3 + 3101
coreaS3 = coreaS3 + 1126
canada3 = canada3 + 785

# %%
ago2018 = pd.read_csv('2018\Agosto2018.csv')
ago3 = ago2018.groupby('pais').count()
ago3 = ago3.sort_values(by ='Marca', ascending=False)
ago3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          11562              11562                11562
# JAPON                           5462               5462                 5462
# INDIA                           4984               4984                 4984
# ESTADOS UNIDOS                  3107               3107                 3107
# COREA DEL SUR                   1223               1223                 1223
# CANADA                           835                835                  835
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         11562                11562  11562  11562
# JAPON                          5462                 5462   5462   5462
# INDIA                          4984                 4984   4984   4984
# ESTADOS UNIDOS                 3107                 3107   3107   3107
# ...

# %%
china3 = china3 + 11562
japon3 = japon3 + 5462
india3 = india3 + 4984
usa3 = usa3 + 3107
coreaS3 = coreaS3 + 1223
canada3 = canada3 + 835

# %%
sep2018 = pd.read_csv('2018\Septiembre2018.csv')
sep3 = sep2018.groupby('pais').count()
sep3 = sep3.sort_values(by ='Marca', ascending=False)
sep3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           9641               9641                 9641
# INDIA                           6272               6272                 6272
# JAPON                           4926               4926                 4926
# ESTADOS UNIDOS                  2817               2817                 2817
# COREA DEL SUR                    848                848                  848
# CANADA                           726                726                  726
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          9641                 9641   9641   9641
# INDIA                          6272                 6272   6272   6272
# JAPON                          4926                 4926   4926   4926
# ESTADOS UNIDOS                 2817                 2817   2817   2817
# ...

# %%
china3 = china3 + 9641
india3 = india3 + 6272
japon3 = japon3 + 4926
usa3 = usa3 + 2817
coreaS3 = coreaS3 + 848
canada3 = canada3 + 726

# %%
oct2018 = pd.read_csv('2018\Octubre2018.csv')
oct3 = oct2018.groupby('pais').count()
oct3 = oct3.sort_values(by ='Marca', ascending=False)
oct3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          14284              14284                14284
# INDIA                           6797               6797                 6797
# JAPON                           5177               5177                 5177
# ESTADOS UNIDOS                  3153               3153                 3153
# COREA DEL SUR                   1282               1282                 1282
# CANADA                           818                818                  818
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         14284                14284  14284  14284
# INDIA                          6797                 6797   6797   6797
# JAPON                          5177                 5177   5177   5177
# ESTADOS UNIDOS                 3153                 3153   3153   3153
# ...

# %%
china3 = china3 + 14284
india3 = india3 + 6797
japon3 = japon3 + 5177
usa3 = usa3 + 3153
coreaS3 = coreaS3 + 1282
canada3 = canada3 + 818

# %%
nov2018 = pd.read_csv('2018\_Noviembre2018.csv')
nov3 = nov2018.groupby('pais').count()
nov3 = nov3.sort_values(by ='Marca', ascending=False)
nov3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          11224              11224                11224
# INDIA                           6176               6176                 6176
# JAPON                           5381               5381                 5381
# ESTADOS UNIDOS                  3282               3282                 3282
# COREA DEL SUR                   1103               1103                 1103
# CANADA                           794                794                  794
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         11224                11224  11224  11224
# INDIA                          6176                 6176   6176   6176
# JAPON                          5381                 5381   5381   5381
# ESTADOS UNIDOS                 3282                 3282   3282   3282
# ...

# %%
china3 = china3 + 11224
india3 = india3 + 6176
japon3 = japon3 + 5381
usa3 = usa3 + 3282
coreaS3 = coreaS3 + 1103
canada3 = canada3 + 794

# %%
dic2018 = pd.read_csv('2018\Diciembre2018.csv')
dic3 = dic2018.groupby('pais').count()
dic3 = dic3.sort_values(by ='Marca', ascending=False)
dic3.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           8466               8466                 8466
# INDIA                           5997               5997                 5997
# JAPON                           5992               5992                 5992
# ESTADOS UNIDOS                  3927               3927                 3927
# COREA DEL SUR                   1220               1220                 1220
# CANADA                           868                868                  868
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          8466                 8466   8466   8458
# INDIA                          5997                 5997   5997   5997
# JAPON                          5992                 5992   5992   5992
# ESTADOS UNIDOS                 3927                 3927   3927   3927
# ...

# %%
china3 = china3 + 8466
india3 = india3 + 5997
japon3 = japon3 + 5997
usa3 = usa3 + 3927
coreaS3 = coreaS3 + 1220
canada3 = canada3 + 868

# %%
paises2018 = [china3,japon3,india3,usa3,coreaS3]
nombres = ["China","Japon","India","USA","Corea del sur"]
plt.pie(paises2018, labels=nombres)
plt.show()

# %% [markdown]
# # ¿De qué países se están importando más vehículos? 2019

# %%
ene2019 = pd.read_csv('2019\Enero2019.csv')
ene4 = ene2019.groupby('pais').count()
ene4 = ene4.sort_values(by ='Marca', ascending=False)
ene4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          12210              12210                12210
# JAPON                           4539               4539                 4539
# INDIA                           3848               3848                 3848
# ESTADOS UNIDOS                  2421               2421                 2421
# COREA DEL SUR                    922                922                  922
# CANADA                           745                745                  745
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         12210                12210  12210  12210
# JAPON                          4539                 4539   4539   4539
# INDIA                          3848                 3848   3848   3848
# ESTADOS UNIDOS                 2421                 2421   2421   2421
# ...

# %%
china4 = 12210
japon4 = 4539
india4 = 3848
usa4 = 2421
coreaS4 = 922
canada4 = 745

# %%
feb2019 = pd.read_csv('2019\Febrero2019.csv')
feb4 = feb2019.groupby('pais').count()
feb4 = feb4.sort_values(by ='Marca', ascending=False)
feb4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          10743              10743                10743
# INDIA                           5314               5314                 5314
# JAPON                           4985               4985                 4985
# ESTADOS UNIDOS                  2770               2770                 2770
# COREA DEL SUR                   1225               1225                 1225
# CANADA                           794                794                  794
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         10743                10743  10743  10743
# INDIA                          5314                 5314   5314   5314
# JAPON                          4985                 4985   4985   4985
# ESTADOS UNIDOS                 2770                 2770   2770   2770
# ...

# %%
china4 = china4 + 10743
india4 = india4 + 5314
japon4 = japon4 + 4985
usa4 = usa4 + 2770
coreaS4 = coreaS4 + 1225
canada4 = canada4 + 794

# %%
mar2019 = pd.read_csv('2019\Marzo2019.csv')
mar4 = mar2019.groupby('pais').count()
mar4 = mar4.sort_values(by ='Marca', ascending=False)
mar4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           6759               6759                 6759
# JAPON                           5473               5473                 5473
# INDIA                           4844               4844                 4844
# ESTADOS UNIDOS                  3045               3045                 3045
# COREA DEL SUR                   1005               1005                 1005
# CANADA                           896                896                  896
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          6759                 6759   6759   6755
# JAPON                          5473                 5473   5473   5473
# INDIA                          4844                 4844   4844   4844
# ESTADOS UNIDOS                 3045                 3045   3045   3045
# ...

# %%
china4 = china4 + 6759
japon4 = japon4 + 5473
india4 = india4 + 4844
usa4 = usa4 + 3045
coreaS4 = coreaS4 + 1005
canada4 = canada4 + 896

# %%
abr2019 = pd.read_csv('2019\Abril2019.csv')
abr4 = abr2019.groupby('pais').count()
abr4 = abr4.sort_values(by ='Marca', ascending=False)
abr4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           7601               7601                 7601
# JAPON                           5258               5258                 5258
# INDIA                           3820               3820                 3820
# ESTADOS UNIDOS                  2952               2952                 2952
# COREA DEL SUR                   1314               1314                 1314
# CANADA                           810                810                  810
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          7601                 7601   7601   7601
# JAPON                          5258                 5258   5258   5258
# INDIA                          3820                 3820   3820   3820
# ESTADOS UNIDOS                 2952                 2952   2952   2952
# ...

# %%
china4 = china4 + 7601
japon4 = japon4 + 5258
india4 = india4 + 3820
usa4 = usa4 + 2952
coreaS4 = coreaS4 + 1314
canada4 = canada4 + 810

# %%
may2019 = pd.read_csv('2019\Mayo2019.csv')
may4 = may2019.groupby('pais').count()
may4 = may4.sort_values(by ='Marca', ascending=False)
may4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           9003               9003                 9003
# INDIA                           5464               5464                 5464
# JAPON                           5017               5017                 5017
# ESTADOS UNIDOS                  3015               3015                 3015
# COREA DEL SUR                   1481               1481                 1481
# CANADA                           853                853                  853
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          9003                 9003   9003   9003
# INDIA                          5464                 5464   5464   5464
# JAPON                          5017                 5017   5017   5017
# ESTADOS UNIDOS                 3015                 3015   3015   3015
# ...

# %%
china4 = china4 + 9003
india4 = india4 + 5664
japon4 = japon4 + 5017
usa4 = usa4 + 3015
coreaS4 = coreaS4 + 1481
canada4 = canada4 + 853

# %%
jun2019 = pd.read_csv('2019\Junio2019.csv')
jun4 = jun2019.groupby('pais').count()
jun4 = jun4.sort_values(by ='Marca', ascending=False)
jun4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           5641               5641                 5641
# INDIA                           4649               4649                 4649
# JAPON                           4648               4648                 4648
# ESTADOS UNIDOS                  2819               2819                 2819
# COREA DEL SUR                    993                993                  993
# CANADA                           740                740                  740
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          5641                 5641   5641   5641
# INDIA                          4649                 4649   4649   4649
# JAPON                          4648                 4648   4648   4648
# ESTADOS UNIDOS                 2819                 2819   2819   2819
# ...

# %%
china4 = china4 + 5641
india4 = india4 + 4649
japon4 = japon4 + 4648
usa4 = usa4 + 2819
coreaS4 = coreaS4 + 993
canada4 = canada4 + 740

# %%
jul2019 = pd.read_csv('2019\Julio2019.csv')
jul4 = jul2019.groupby('pais').count()
jul4 = jul4.sort_values(by ='Marca', ascending=False)
jul4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          12818              12818                12818
# INDIA                           5755               5755                 5755
# JAPON                           5354               5354                 5354
# ESTADOS UNIDOS                  3125               3125                 3125
# COREA DEL SUR                   1361               1361                 1361
# CANADA                           861                861                  861
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         12818                12818  12818  12818
# INDIA                          5755                 5755   5755   5755
# JAPON                          5354                 5354   5354   5354
# ESTADOS UNIDOS                 3125                 3125   3125   3125
# ...

# %%
china4 = china4 + 12818
india4 = india4 + 5755
japon4 = japon4 + 5354
usa4 = usa4 + 3125
coreaS4 = coreaS4 + 1361
canada4 = canada4 + 861

# %%
ago2019 = pd.read_csv('2019\Agosto2019.csv')
ago4 = ago2019.groupby('pais').count()
ago4 = ago4.sort_values(by ='Marca', ascending=False)
ago4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           7812               7812                 7812
# INDIA                           6352               6352                 6352
# JAPON                           5250               5250                 5250
# ESTADOS UNIDOS                  3268               3268                 3268
# COREA DEL SUR                   1186               1186                 1186
# CANADA                           932                932                  932
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          7812                 7812   7812   7812
# INDIA                          6352                 6352   6352   6352
# JAPON                          5250                 5250   5250   5250
# ESTADOS UNIDOS                 3268                 3268   3268   3268
# ...

# %%
china4 = china4 + 7812
india4 = india4 + 6352
japon4 = japon4 + 5250
usa4 = usa4 + 3268
coreaS4 = coreaS4 + 1186
canada4 = canada4 + 932

# %%
sep2019 = pd.read_csv('2019\Septiembre2019.csv')
sep4 = sep2019.groupby('pais').count()
sep4 = sep4.sort_values(by ='Marca', ascending=False)
sep4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                           8990               8990                 8990
# INDIA                           5516               5516                 5516
# JAPON                           4983               4983                 4983
# ESTADOS UNIDOS                  3031               3031                 3031
# COREA DEL SUR                   1491               1491                 1491
# CANADA                           865                865                  865
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                          8990                 8990   8990   8990
# INDIA                          5516                 5516   5516   5516
# JAPON                          4983                 4983   4983   4983
# ESTADOS UNIDOS                 3031                 3031   3031   3031
# ...

# %%
china4 = china4 + 8990
india4 = india4 + 5516
japon4 = japon4 + 4983
usa4 = usa4 + 3031
coreaS4 = coreaS4 + 1491
canada4 = canada4 + 865

# %%
nov2019 = pd.read_csv('2019\_Noviembre2019.csv')
nov4 = nov2019.groupby('pais').count()
nov4 = nov4.sort_values(by ='Marca', ascending=False)
nov4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          14148              14148                14148
# INDIA                           7661               7661                 7661
# JAPON                           5763               5763                 5763
# ESTADOS UNIDOS                  3436               3436                 3436
# COREA DEL SUR                   1725               1725                 1725
# CANADA                           929                929                  929
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         14148                14148  14148  14148
# INDIA                          7661                 7661   7661   7661
# JAPON                          5763                 5763   5763   5763
# ESTADOS UNIDOS                 3436                 3436   3436   3436
# ...

# %%
china4 = china4 + 14148
india4 = india4 + 7661
japon4 = japon4 + 5763
usa4 = usa4 + 3436
coreaS4 = coreaS4 + 1725
canada4 = canada4 + 929

# %%
dic2019 = pd.read_csv('2019\Diciembre2019.csv')
dic4 = dic2019.groupby('pais').count()
dic4 = dic4.sort_values(by ='Marca', ascending=False)
dic4.head(6)
# Out:
#                 Pais de Proveniencia  Aduana de Ingreso   Fecha de la Poliza  \
# pais
# CHINA                          14862              14862                14862
# INDIA                           7185               7185                 7185
# JAPON                           6173               6173                 6173
# ESTADOS UNIDOS                  4241               4241                 4241
# COREA DEL SUR                   1245               1245                 1245
# CANADA                          1047               1047                 1047
#
#                 Partida Arancelaria  Modelo del Vehiculo  Marca  Linea  \
# pais
# CHINA                         14862                14862  14862  14862
# INDIA                          7185                 7185   7185   7185
# JAPON                          6173                 6173   6173   6173
# ESTADOS UNIDOS                 4241                 4241   4241   4241
# ...

# %%
china4 = china4 + 14862
india4 = india4 + 7185
japon4 = japon4 + 6173
usa4 = usa4 + 4241
coreaS4 = coreaS4 + 1245
canada4 = canada4 + 1047

# %%
paises2019 = [china4,japon4,india4,usa4,coreaS4]
nombres = ["China","Japon","India","USA","Corea del sur"]
plt.pie(paises2019, labels=nombres)
plt.show()
