# %%
# Librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ene2016 = pd.read_csv('2016\Enero2016.csv')
ene2016.head(1000)
# Out:
#     Pais_de_Proveniencia        Aduana de Ingreso  Fecha de la Poliza  \
# 0         ESTADOS UNIDOS           PUERTO BARRIOS          14/01/2016
# 1                  JAPON           PUERTO QUETZAL          26/01/2016
# 2         ESTADOS UNIDOS           PUERTO BARRIOS          09/01/2016
# 3         ESTADOS UNIDOS           PUERTO BARRIOS          27/01/2016
# 4         ESTADOS UNIDOS           PUERTO BARRIOS          23/01/2016
# ..                   ...                      ...                 ...
# 995                CHINA           PUERTO QUETZAL          08/01/2016
# 996       ESTADOS UNIDOS           PUERTO BARRIOS          19/01/2016
# 997       ESTADOS UNIDOS  SANTO TOMAS DE CASTILLA          20/01/2016
# 998               MEXICO                EL CARMEN          22/01/2016
# 999       ESTADOS UNIDOS           PUERTO BARRIOS          04/02/2016
#
#      Partida Arancelaria  Modelo_del_Vehiculo      Marca  \
# 0               87032379                 2007      ACURA
# ...

# %%
ene2016.Modelo_del_Vehiculo
# Out:
# 0        2007
# 1        2002
# 2        2004
# 3        2003
# 4        1997
#          ...
# 20811    2015
# 20812    2015
# 20813    2015
# 20814    2015
# 20815    2015
# Name: Modelo_del_Vehiculo, Length: 20816, dtype: int64
